# %%
# Step 1: Import
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Step 2: Load dataset
url = "https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
df = pd.read_csv(url)
df.columns = ['YearsExperience', 'Salary']


# Step 3: Visualize data
plt.scatter(df['YearsExperience'], df['Salary'], color='blue')
# Draw the learned regression line
plt.plot(df['YearsExperience'], model.predict(df[['YearsExperience']]), color='red', label='Learned Line')
plt.legend()
plt.show()
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
plt.show()

# Step 4: Prepare data
X = df[['YearsExperience']]
y = df['Salary']

# Step 5: Train model
model = LinearRegression()
model.fit(X, y)

# Step 6: Print learned formula
print(f"Slope (m): {model.coef_[0]:.2f}")
print(f"Intercept (b): {model.intercept_:.2f}")
print(f"Formula: Salary = {model.coef_[0]:.2f} * Experience + {model.intercept_:.2f}")

# Step 7: Predict a new salary
exp = 7.5
pred_salary = model.predict([[exp]])
print(f"Predicted Salary for {exp} years experience = ${pred_salary[0]:.2f}")
# Out:
# Slope (m): 9.78
# Intercept (b): 2.48
# Formula: Salary = 9.78 * Experience + 2.48
# Predicted Salary for 7.5 years experience = $75.80
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
